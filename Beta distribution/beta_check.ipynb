# %% [markdown]
# # Beta distribution
#
# Notebook for the check of distribution

# %% [markdown]
# ### Mount Drive

# %%
# mount my drive
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# The following path has to be adjusted if necessary:

# %%
# %run "/content/drive/My Drive/Colab Notebooks/Utils.ipynb"
# %run "/content/drive/My Drive/Colab Notebooks/Plot_fcts.ipynb"
# Out:
#      |████████████████████████████████| 368kB 3.4MB/s
#   Building wheel for qmcpy (setup.py) ... done
#      |████████████████████████████████| 430kB 3.2MB/s

# %% [markdown]
# ### Imports

# %%
! pip install qmcpy --quiet

# %%
import numpy as np
import qmcpy

# %% [markdown]
# ### Sampling

# %%
np.random.seed(111)

# %% [markdown]
# Set parameters:

# %%
m = 5000                               # number of true samples
theta = np.array([2,5])                # true theta
d = 1                                  # dimensions of data
p = theta.shape[0]                     # dimensions of parameter space

# %% [markdown]
# Define the QMC sequence:

# %%
qmc = qmcpy.Halton(theta[0]+theta[1])

# %% [markdown]
# Sample from the g-and-k distribution:

# %%
y = sample_beta('MC',m,d,theta)

# %% [markdown]
# Plot the resulting distribution

# %%
plot_beta(y,(12,6),theta)
